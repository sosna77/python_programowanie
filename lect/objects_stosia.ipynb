# %%
class SmartPhone:
    pass

# %%
sp=SmartPhone()

# %%
type(sp), isinstance(sp, SmartPhone)
# Out:
# (__main__.SmartPhone, True)

# %% [markdown]
# #konstruktor

# %%
class SmartPhone:
    name = ""
    address_book = {}
    

    def __init__(self):
        print('policja gurom')

# %%
sp = SmartPhone()
sp.name = "ciozga's phone"
sp.address_book['ciozga'] = '987-654-321'
sp.address_book['Alice'] = "123-456-789"
# Out:
# policja gurom

# %%
sp.name , sp.address_book
# Out:
# ("ciozga's phone", {'ciozga': '987-654-321', 'Alice': '123-456-789'})

# %%
spB = SmartPhone()
spB.name = "ciozga's phone"
spB.address_book['Alice'] = "8953247896539275"
spB.address_book['ciozga'] = '123-4564-78'

spA= SmartPhone()
spA.name = "bob's phone"
spA.address_book['bob'] = "987-654-321"
spA.address_book['ciozga'] = '123-4564-78'
# Out:
# policja gurom
# policja gurom

# %%
spA.name,spA.address_book
# Out:
# ("bob's phone",
#  {'ciozga': '123-4564-78', 'Alice': '8953247896539275', 'bob': '987-654-321'})

# %%
spB.name, spB.address_book
# Out:
# ("ciozga's phone",
#  {'ciozga': '123-4564-78', 'Alice': '8953247896539275', 'bob': '987-654-321'})

# %% [markdown]
# Lepiej zdefiniowac goscia w konstruktorze. Atrybuciki z klasy dla kazdego obiektu som unikalne, ciooo

# %%
class SmartPhone:
  

    def __init__(self, name):
        print('policja gurom')
        self.name = name
        self.address_book = {}

# %%
spB = SmartPhone("ciozga's phone")

spB.address_book['Alice'] = "8953247896539275"
spB.address_book['ciozga'] = '123-4564-78'

spA= SmartPhone("bob's phone")

spA.address_book['bob'] = "987-654-321"
spA.address_book['ciozga'] = '123-4564-78'
# Out:
# policja gurom
# policja gurom

# %%
spA.name , spA.address_book
# Out:
# ("bob's phone", {'bob': '987-654-321', 'ciozga': '123-4564-78'})

# %%
spB.name , spB.address_book
# Out:
# ("ciozga's phone", {'Alice': '8953247896539275', 'ciozga': '123-4564-78'})

# %% [markdown]
# pqjton nie zabrania dodawania atrybutow do obiektow

# %%
spA.hakunamatata = "it means CAA? ~ murba w zoo"
spA.hakunamatata
# Out:
# 'it means CAA? ~ murba w zoo'

# %% [markdown]
# dodajemy metody
# do klassy

# %%
class SmartPhone:
  

    def __init__(self, name):
        print('policja gurom')
        self.name = name
        self.address_book = {}

    def reset(self):
        print(f'reseting murba {self.name} ')

# %%
spB = SmartPhone("ciozga's phone")

spB.address_book['Alice'] = "8953247896539275"
spB.address_book['ciozga'] = '123-4564-78'
# Out:
# policja gurom

# %%
spB.reset()
# Out:
# reseting murba ciozga's phone

# %% [markdown]
# jesli jest _nazwa to takie prywatne nie dotykac!!!

# %%
import random

class SmartPhone:
  

    def __init__(self, name):
        print('policja gurom')
        self.name = name
        self.address_book = {}
        self._secret_code = random.randint(1000,9999)


    def reset(self):
        print(f'reseting murba {self.name} ')
    def send_data_to_china(self):
        print(f'sending {self._secret_code}')

# %%
spB = SmartPhone("ciozga's phone")

spB.address_book['Alice'] = "8953247896539275"
spB.address_book['ciozga'] = '123-4564-78'
spB.send_data_to_china()
# Out:
# policja gurom
# sending 3379

# %%
spB._secret_code = "1234"

# %%
spB.send_data_to_china()
# Out:
# sending 1234

# %%
print(spB)
# Out:
# <__main__.SmartPhone object at 0x7fa661b87620>

# %%
import random

class SmartPhone:
  

    def __init__(self, name):
        print('policja gurom')
        self.name = name
        self.address_book = {}
        self._secret_code = random.randint(1000,9999)


    def reset(self):
        print(f'reseting murba {self.name} ')
    def send_data_to_china(self):
        print(f'sending {self._secret_code}')
    def __str__(self):
        return f'SmartPhone(name=(self.name), address_book=(self.address_book))'
    def __getitem__(self,key):
        return self.address_book[key]
    
    def __setitem__(self,key,value):
        self.address_book[key] = value

    def __len__(self):
        return len(self.address_book)

# %%
spB = SmartPhone("ciozga's phone")

spB.address_book['Alice'] = "8953247896539275"
spB.address_book['ciozga'] = '123-4564-78'
spB['Alice']
# Out:
# policja gurom
# '8953247896539275'

# %%
spB['Alice'] = '777777777'
spB['Alice']
# Out:
# '777777777'

# %%
len(spB)
# Out:
# 2

# %% [markdown]
# dźedźczenie

# %%
class ElectronicDevice:
    def __init__(self,name):
        print('ebe')
        self.name=name

    def restart(self):
        print(f'resetin {self.name}')

class Computer(ElectronicDevice):
    pass

# %%
mypc=Computer('mypc')
mypc.restart()
# Out:
# ebe
# resetin mypc

# %% [markdown]
# MRO(lester)- method resolution order

# %%
Computer.__mro__
# Out:
# (__main__.Computer, __main__.ElectronicDevice, object)

# %%
class ElectronicDevice:
    def __init__(self,name=""):
        print('ebe')
        self.name=name

    def restart(self):
        print(f'resetin {self.name}')
    def update_firmware(self):
        print(f'updating cwyla ciozge for {self.name}')
        ElectronicDevice.restart(self)

class Computer(ElectronicDevice):
    def __init__(self,name,ram):
        super().__init__(name)
        self.ram=ram
        print(' creationg a komputr')
    def __str__(self):
        return f'Computer name={self.name}, ram={self.ram}'
    def restart(self):
        print(f'saving cwyl ciozge do {self.name}')
        super().restart()

# %%
pc7=Computer('siedem',7)
pc7.restart()
# Out:
# ebe
#  creationg a komputr
# saving cwyl ciozge do siedem
# resetin siedem

# %%
pc7.update_firmware()
# Out:
# updating cwyla ciozge for siedem
# resetin siedem

# %%
class ElectronicDevice:
    def __init__(self,name,**kwargs):
        print('ebe')
        self.name=name

    def restart(self):
        print(f'resetin {self.name}')


    __restart = restart


    def update_firmware(self):
        print(f'updating cwyla ciozge for {self.name}')
        self.__restart



class Computer(ElectronicDevice):
    def __init__(self,name,ram):
        super().__init__(name)
        self.ram=ram
        print(' creationg a komputr')
    def __str__(self):
        return f'Computer name={self.name}, ram={self.ram}'
    def restart(self):
        print(f'saving cwyl ciozge do {self.name}')
        super().restart()

# %%
mypc=Computer('mujpc',7)
mypc.restart()
# Out:
# ebe
#  creationg a komputr
# saving cwyl ciozge do mujpc
# resetin mujpc

# %%
class ElectronicDevice:
    def __init__(self,name='', **kwargs):
        print('ebe')
        self.name=name

    def restart(self):
        print(f'resetin {self.name}')


    __restart = restart


    def update_firmware(self):
        print(f'updating cwyla ciozge for {self.name}')
        self.__restart



class Computer(ElectronicDevice):
    def __init__(self,ram=0, **kwargs):
        super().__init__(*kwargs)
        self.ram=ram
        print(' creationg a komputr')
    def __str__(self):
        return f'Computer name={self.name}, ram={self.ram}'
    def restart(self):
        print(f'saving cwyl ciozge do {self.name}')
        super().restart()



class Camera(ElectronicDevice):
    def __init__(self, width=0, height=0,**kwargs):
        print('creuje kamere')
        super().__init__(**kwargs)
        self.width= width
        self.height = height
    def restart(self):
        print(f'bakuje do kamery zdj do {self.name}')
        super().restart()

class smartphone(Computer, Camera):
    def __init__(self, name, ram, width, height):
        print('creauj smartfona')
        args={'name': name, 'ram': ram, 'width': width, 'height': height}
        super().__init__(**args)

# %%
2+2
# Out:
# 4

# %%
phone = smartphone()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 phone = smartphone()
#
# TypeError: smartphone.__init__() missing 4 required positional arguments: 'name', 'ram', 'width', and 'height'

# %% [markdown]
# ledygraesja

# %%
def some_func(x,y=1):
    return x+y

# %%
args=[1,2]
some_func(*args)
#pajton gwiadkom odpakowuje liste ebe ebe ebe ebe ebe
args={'x':1, 'y':2}
some_func(**args)
# Out:
# 3

# %%
args = {1}
kwargs = {'y':2}
some_func(*args, **kwargs)
# Out:
# 3

# %%
def some_func(x,y,*args,z=4, **kwargs):
    print(f'x={x},y={y},args={args},z={z},kwargs={kwargs}')

# %%
some_func(1,2,3,4,5,z=7, ebe=7, diddy=7, dihlet=67, jeff=3, charlie=4)
# Out:
# x=1,y=2,args=(3, 4, 5),z=7,kwargs={'ebe': 7, 'diddy': 7, 'dihlet': 67, 'jeff': 3, 'charlie': 4}
